# %%
print("this is my first pandas program")
# Out:
# this is my first pandas program

# %%
a=3
b=2
print(a*b)
print(a+b)
# Out:
# 6
# 5

# %%
import pandas as pd
import numpy as np
nith=np.array([2,2,34,44])
ser=pd.Series(nith)
print(ser)
# Out:
# 0     2
# 1     2
# 2    34
# 3    44
# dtype: int32

# %%
import pandas as pd
import numpy as np
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks']  
ser=pd.Series(lst)
print(ser)
# Out:
# 0     Geeks
# 1       For
# 2     Geeks
# 3        is
# 4    portal
# 5       for
# 6     Geeks
# dtype: object

# %%
import pandas as pd

lst = {'date':['Geeks', 'For', 'Geeks', 'for', 'Geeks']  ,
       'temp':[32,23,45,5,55],
       'event':['x','u','a','n','b']
      }
       
df=pd.DataFrame(lst)
df
# Out:
#     date  temp event
# 0  Geeks    32     x
# 1    For    23     u
# 2  Geeks    45     a
# 3    for     5     n
# 4  Geeks    55     b

# %%
import pandas as pd
import numpy as np
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks']  
ser=pd.Series(lst,index=["x","y","z","a","b","c","d"])
print(ser)
# Out:
# x     Geeks
# y       For
# z     Geeks
# a        is
# b    portal
# c       for
# d     Geeks
# dtype: object

# %%
import pandas as pd
import numpy as np
lst = {"day1": 'Geeks', "day2":'For', "day3":'Geeks'}  
ser=pd.Series(lst)
print(ser)
# Out:
# day1    Geeks
# day2      For
# day3    Geeks
# dtype: object

# %%
import pandas as pd
df = pd.read_excel('C:\\Users\\selva\\Desktop\\NITHIYA.xlsx')
df
# Out:
#       day         city  temperature  windspeed  event
# 0   42736         york           32          6   rain
# 1   42773          new           36          8  sunny
# 2   42774    hyderabad           37          9  sunny
# 3   42775          new           38         10  sunny
# 4   42776    bangalore           39         11  sunny
# 5   42777          new           40         12  sunny
# 6   42778       cochin           41         13  sunny
# 7   42779       mumbai           42         14  sunny
# 8   42780          new           43         15  sunny
# 9   42781  tirunelveli           44         16  sunny
# 10  42782        paris           45         17  sunny
# 11  42783          new           46         18  sunny
# 12  42784    nagercoil           47         19  sunny

# %%
df.shape
# Out:
# (13, 5)

# %%
df.shape
# Out:
# (13, 5)

# %%
row,col=df.shape
row
# Out:
# 13

# %%
row,col=df.shape
col
# Out:
# 5

# %%
df.head()
# Out:
#      day       city  temperature  windspeed  event
# 0  42736       york           32          6   rain
# 1  42773        new           36          8  sunny
# 2  42774  hyderabad           37          9  sunny
# 3  42775        new           38         10  sunny
# 4  42776  bangalore           39         11  sunny

# %%
df.head(5)
# Out:
#      day       city  temperature  windspeed  event
# 0  42736       york           32          6   rain
# 1  42773        new           36          8  sunny
# 2  42774  hyderabad           37          9  sunny
# 3  42775        new           38         10  sunny
# 4  42776  bangalore           39         11  sunny

# %%
df.tail(12)
# Out:
#       day         city  temperature  windspeed  event
# 1   42773          new           36          8  sunny
# 2   42774    hyderabad           37          9  sunny
# 3   42775          new           38         10  sunny
# 4   42776    bangalore           39         11  sunny
# 5   42777          new           40         12  sunny
# 6   42778       cochin           41         13  sunny
# 7   42779       mumbai           42         14  sunny
# 8   42780          new           43         15  sunny
# 9   42781  tirunelveli           44         16  sunny
# 10  42782        paris           45         17  sunny
# 11  42783          new           46         18  sunny
# 12  42784    nagercoil           47         19  sunny

# %%
df[2:6]
# Out:
#      day       city  temperature  windspeed  event
# 2  42774  hyderabad           37          9  sunny
# 3  42775        new           38         10  sunny
# 4  42776  bangalore           39         11  sunny
# 5  42777        new           40         12  sunny

# %%
df.columns
# Out:
# Index(['day', 'city', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.columns
# Out:
# Index(['day', 'city', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
type(df['city'])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#       day         city  temperature  windspeed  event
# 0   42736         york           32          6   rain
# 1   42773          new           36          8  sunny
# 2   42774    hyderabad           37          9  sunny
# 3   42775          new           38         10  sunny
# 4   42776    bangalore           39         11  sunny
# 5   42777          new           40         12  sunny
# 6   42778       cochin           41         13  sunny
# 7   42779       mumbai           42         14  sunny
# 8   42780          new           43         15  sunny
# 9   42781  tirunelveli           44         16  sunny
# 10  42782        paris           45         17  sunny
# 11  42783          new           46         18  sunny
# 12  42784    nagercoil           47         19  sunny

# %%
df['temperature'].max()
# Out:
# 47

# %%
df['temperature'].min()
# Out:
# 32

# %%
df['temperature'].mean()
# Out:
# 40.76923076923077

# %%
df.describe()
# Out:
#                 day  temperature  windspeed
# count     13.000000    13.000000  13.000000
# mean   42775.230769    40.769231  12.923077
# std       12.282466     4.342692   4.030334
# min    42736.000000    32.000000   6.000000
# 25%    42775.000000    38.000000  10.000000
# 50%    42778.000000    41.000000  13.000000
# 75%    42781.000000    44.000000  16.000000
# max    42784.000000    47.000000  19.000000

# %%
df[df.city=="new"]
# Out:
#       day city  temperature  windspeed  event
# 1   42773  new           36          8  sunny
# 3   42775  new           38         10  sunny
# 5   42777  new           40         12  sunny
# 8   42780  new           43         15  sunny
# 11  42783  new           46         18  sunny

# %%
import pandas as pd
df = pd.read_excel('C:\\Users\\selva\\Desktop\\NITHIYA.xlsx')
df
# Out:
#       day         city  temperature  windspeed  event
# 0   42736         york           32          6   rain
# 1   42773          new           36          8  sunny
# 2   42774    hyderabad           37          9  sunny
# 3   42775          new           38         10  sunny
# 4   42776    bangalore           39         11  sunny
# 5   42777          new           40         12  sunny
# 6   42778       cochin           41         13  sunny
# 7   42779       mumbai           42         14  sunny
# 8   42780          new           43         15  sunny
# 9   42781  tirunelveli           44         16  sunny
# 10  42782        paris           45         17  sunny
# 11  42783          new           46         18  sunny
# 12  42784    nagercoil           47         19  sunny

# %%
df[df.temperature==df.temperature.max()]
# Out:
#       day       city  temperature  windspeed  event
# 12  42784  nagercoil           47         19  sunny

# %%
df['city'][df.temperature==df.temperature.max()]
# Out:
# 12    nagercoil
# Name: city, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=13, step=1)

# %%
df.reset_index()
df
# Out:
#       day         city  temperature  windspeed  event
# 0   42736         york           32          6   rain
# 1   42773          new           36          8  sunny
# 2   42774    hyderabad           37          9  sunny
# 3   42775          new           38         10  sunny
# 4   42776    bangalore           39         11  sunny
# 5   42777          new           40         12  sunny
# 6   42778       cochin           41         13  sunny
# 7   42779       mumbai           42         14  sunny
# 8   42780          new           43         15  sunny
# 9   42781  tirunelveli           44         16  sunny
# 10  42782        paris           45         17  sunny
# 11  42783          new           46         18  sunny
# 12  42784    nagercoil           47         19  sunny

# %%
df.reset_index()
df
# Out:
#       day         city  temperature  windspeed  event
# 0   42736         york           32          6   rain
# 1   42773          new           36          8  sunny
# 2   42774    hyderabad           37          9  sunny
# 3   42775          new           38         10  sunny
# 4   42776    bangalore           39         11  sunny
# 5   42777          new           40         12  sunny
# 6   42778       cochin           41         13  sunny
# 7   42779       mumbai           42         14  sunny
# 8   42780          new           43         15  sunny
# 9   42781  tirunelveli           44         16  sunny
# 10  42782        paris           45         17  sunny
# 11  42783          new           46         18  sunny
# 12  42784    nagercoil           47         19  sunny
